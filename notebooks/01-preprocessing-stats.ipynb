# %%
from copy import deepcopy as copy
import datetime
import json
from math import ceil
import multiprocessing
import logging
import operator
import os
import random
import sys
import time
import typing
import warnings

import joblib
from joblib import delayed, Parallel
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from numpy.core.numeric import outer
import pandas as pd
from scipy.stats import mode, entropy
import seaborn as sns
import sklearn.feature_selection
import sklearn.metrics
from sklearn.metrics import roc_auc_score
import sklearn.model_selection
import typer
from tqdm.auto import tqdm

root = os.path.dirname(os.getcwd())
os.chdir(root)

import src

# %% [markdown]
# # Preprocessing of port calls data

# %%
inspections = (
    pd.read_csv("data/raw/inspections.csv", engine='python', index_col=0, skipfooter=1, parse_dates=['DateOfFirstVisit', 'ShipKeelLayingDate'], dtype={'WasDetained': bool})
    .sort_values('DateOfFirstVisit')
)

with open('data/raw/parismou_performancelist.json') as file:
    performance_list = json.load(file)

portcalls = (
    pd.read_csv('data/raw/portcalls_new.csv', sep=';', low_memory=False, index_col=0)
    .rename(
        columns={
            'ATA_LT': 'arrival',
            'ATD_LT': 'departure',
            'Port.Location.Name': 'port',
            'IMO.Number': 'ship',
            'X.ATA..Ship.Risk.Profile': 'risk',
            'X.ATA..Ship.Flag.Code': 'flag',
            'X.ATA..Ship.Keel.Laying.Date': 'keel_laying',
            'X.ATA..Ship.Type.Description': 'type',
            'X.ATA..Ship.Type.Is.High.Risk': 'type_high_risk',
            'X.ATA..Ship.Flag.Is.PMOU': 'flag_in_pmou',
            'X.ATA..Ship.Priority': 'priority'
        }
    )
    .astype({'port': str, 'ship': str})
    .assign(
        arrival=lambda x: pd.to_datetime(x['arrival']),
        departure=lambda x: pd.to_datetime(x['departure']),
        flag_code=lambda x: x['flag'],
        flag=lambda x: x['flag'].replace(performance_list) != False,
        keel_laying=lambda x: pd.to_datetime(x['keel_laying']),
    )
    .replace({'risk': {'HRS': 2, 'SRS': 1, 'LRS': 0}})
    .sort_values('arrival')
    [[
        'arrival', 'departure', 'port', 'ship', 'risk', 'flag', 
        'keel_laying', 'type', 'type_high_risk', 'flag_in_pmou', 'flag_code',
        'Sent.At', 'priority'
    ]]
)

ships, counts = np.unique(portcalls['ship'], return_counts=True)

portcalls = portcalls.loc[lambda x: x['ship'].isin(set(ships[counts >= 2]))]

# %% [markdown]
# ## Missing risk
# Some port calls miss an entry for the risk.
# Virtually all portcalls with a missing risk, have priority PI.
# This priority is commonly associated with risk 1 and hence we categorize all these portcalls with risk 1.

# %%
portcalls['risk'].isna().value_counts()
# Out:
# False    4921617
# True      467978
# Name: risk, dtype: int64

# %%
portcalls.groupby(['priority'])['risk'].value_counts(normalize=True).sort_index()
# Out:
# priority     risk
# No priority  0.0     0.236096
#              1.0     0.737609
#              2.0     0.026295
# PI           0.0     0.004846
#              1.0     0.948614
#              2.0     0.046540
# PII          0.0     0.146697
#              1.0     0.796522
#              2.0     0.056781
# Name: risk, dtype: float64

# %%
portcalls[portcalls['risk'].isna()]['priority'].value_counts()
# Out:
# PI             377540
# No priority        57
# PII                 1
# Name: priority, dtype: int64

# %%
portcalls['risk'] = portcalls['risk'].fillna(1)

# %% [markdown]
# ## Filter on dates

# %%
fig, ax = plt.subplots(figsize=(4.82,3.21), constrained_layout=True)
portcalls['arrival'].value_counts().resample('M').size().plot(label='portcalls', ax=ax)
inspections['DateOfFirstVisit'].value_counts().resample('M').size().plot(label='inspections', ax=ax)

start_date = datetime.datetime(2014, 1, 1)
end_date = datetime.datetime(2017, 12, 1)

ax.axvline(start_date, 0, 10_000, color='C2')
ax.axvline(end_date, 0, 10_000, color='C2')
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')

ax.set_ylabel('Counts per month')
ax.set_yscale('log')
ax.legend(loc='lower right')
fig.savefig("fig/date-selection.pdf")

# %% [markdown]
# # Stats

# %%
inspections = src.get_inspections()
portcalls = src.get_portcalls()

first_inspection = inspections.groupby('IMO')['DateOfFirstVisit'].first().to_dict()

result = dict()
ship_not_inspected = list()

for ship, group in tqdm(portcalls.groupby('ship')):
    if ship in first_inspection:
        result[ship] = (group['arrival'] < first_inspection[ship]).sum()
    else:
        ship_not_inspected.append(ship)

{
    'number of portcalls': len(portcalls),
    'number of ships': portcalls.ship.nunique(),
    'number of ships without any portcalls': len(set(inspections['IMO'].unique()) - set(portcalls['ship'].unique())),
    'number of ships not inspected': len(ship_not_inspected),
    'fraction of ships not inspected': len(ship_not_inspected) / portcalls.ship.nunique(),
}
# Out:
#   0%|          | 0/28416 [00:00<?, ?it/s]
# {'number of portcalls': 3097752,
#  'number of ships': 28416,
#  'number of ships without any portcalls': 1761,
#  'number of ships not inspected': 6023,
#  'fraction of ships not inspected': 0.2119580518018018}

# %% [markdown]
# ## Number of portcalls before inspection

# %%
fig, ax = plt.subplots(figsize=(4.82,3.21), constrained_layout=True)
sns.ecdfplot(list(result.values()), stat='proportion', ax=ax)
ax.set_xlim(0, 20)
ax.set_xticks(range(20))
ax.set_yticks(np.linspace(0, 1, 11))
ax.grid()
ax.set_xlabel('Number of portcalls before inspection')
fig.savefig("fig/portcalls-before-selection.pdf")

# %% [markdown]
# ## Some ships with many portcalls

# %%
pd.Series(result).sort_values().tail(10)
# Out:
# 9007128     1429
# 9135262     1521
# 7351082     1605
# 8518546     1822
# 8916126     2033
# 9151539     2071
# 9144421     2308
# 9237644     5265
# 9170183     6693
# 9151541    13474
# dtype: int64

# %% [markdown]
# ## Age of ship

# %%
fig, ax = plt.subplots()

sns.ecdfplot(data=portcalls, x='keel_laying', hue='risk', ax=ax)
ax.axvline(portcalls['keel_laying'].max() - pd.DateOffset(years=12), c='black', ls=':')

# %% [markdown]
# ## Type of ship

# %%
(
    portcalls[['type', 'type_high_risk']]
    .drop_duplicates()
    .sort_values('type')
)
# Out:
#                                                     type  type_high_risk
# 3184584                                     Bulk carrier            True
# 1144973                                  Chemical tanker            True
# 2085314                              Combination carrier            True
# 11727                                   Commercial yacht           False
# 3876918                                        Container           False
# 710355                                           Dredger           False
# 778644                                      Fish factory           False
# 1404794                                   Fishing vessel           False
# 2331565                                      Gas carrier            True
# 1396760                       General cargo/multipurpose           False
# 2805493  Government ship used for non-commercial purpose           False
# 5025636                                       Heavy load           False
# 5139970                                 High speed cargo           False
# 985682                        High speed passenger craft            True
# 37146                                  Livestock carrier           False
# 941508                                       MODU & FPSO           False
# 1729894                                       NLS tanker            True
# 5092905                                  Offshore supply           False
# 4207241                                       Oil tanker            True
# 4789737                      Oil tanker/Chemical tanker             True
# 3880050                           Oil tanker/NLS tanker             True
# 824507                          Other special activities           False
# 3848170                                   Passenger ship            True
# 6635                 Pleasure yacht not engaged in trade           False
# 4737757                               Refrigerated cargo           False
# 1734571                                      Ro-Ro cargo           False
# 1860966                             Ro-Ro passenger ship            True
# 765694                              Special purpose ship           False
# 4647233                                              Tug           False
# 1013673                      Warship and naval auxiliary           False
# 2281182                 Wooden ship of a primitive build           False
# 1442152                                              NaN           False

# %% [markdown]
# ## Flag

# %%
with pd.option_context('display.max_rows', 200):
    display(
        portcalls[['flag_in_pmou', 'flag_code']]
        .drop_duplicates()
        .sort_values('flag_code')
    )
# Out:
#          flag_in_pmou           flag_code
# 3708191         False                  AE
# 1630768         False                  AG
# 442437          False                  AL
# 15584           False                  AR
# 1215372         False                  AT
# 374038          False                  AU
# 1466162         False                  AZ
# 476951          False                  BB
# 2076834         False                  BD
# 1302944          True                  BE
# 199626           True                  BG
# 1934860         False                  BH
# 877639          False                  BM
# 513563          False                  BO
# 1844190         False                  BR
# 4540230         False                  BS
# 506362          False                  BZ
# 530286           True                  CA
# 1023777         False                  CD
# 1160594         False                  CG
# 4834704         False                  CH
# 713970          False                  CK
# 1956350         False                  CL
# 331548          False                  CM
# 721553          False                  CN
# 124247          False                  CO
# 2710723         False                  CW
# 4043675          True                  CY
# 665947           True                  DE
# 199007          False                  DJ
# 1396760          True                  DK
# 588690          False                  DM
# 4810092         False                  DZ
# 2208907         False                  EC
# 3135901          True                  EE
# 1480078         False                  EG
# 4207241          True                  ES
# 5013456         False                  ET
# 3770670          True                  FI
# 851427          False                  FK
# 1022478         False                  FM
# 369055          False                  FO
# 2941358          True                  FR
# 1144973          True                  GB
# 332030          False                  GE
# 3164            False                  GG
# 201077          False                  GH
# 4176247         False                  GI
# 761999          False                  GN
# 1299190         False                  GQ
# 1381940          True                  GR
# 1137843         False                  GT
# 18177           False                  GY
# 4374740         False                  HK
# 57287           False                  HN
# 120194           True                  HR
# 60348           False                  ID
# 4778085          True                  IE
# 1720688         False                  IL
# 3339678         False                  IM
# 1520769         False                  IN
# 4166740         False                  IR
# 222422           True                  IS
# 3017613          True                  IT
# 3682808         False                  JE
# 3030725         False                  JM
# 1731243         False                  JO
# 1764878         False                  JP
# 4753988         False                  KH
# 906434          False                  KI
# 437449          False                  KM
# 356993          False                  KN
# 1732069         False                  KR
# 4960843         False                  KW
# 3545990         False                  KY
# 4238784         False                  KZ
# 223246          False                  LB
# 3765519         False                  LK
# 4064634         False                  LR
# 1003655          True                  LT
# 3131491         False                  LU
# 1055203          True                  LV
# 3807706         False                  LY
# 2639813         False                  MA
# 7869            False                  MC
# 675031          False                  MD
# 4906728         False                  ME
# 3662056         False                  MH
# 2879813         False                  MN
# 2040355         False                  MR
# 1734571          True                  MT
# 1652967         False                  MU
# 2286655         False                  MX
# 3560136         False                  MY
# 166296          False                  NG
# 1613551          True                  NL
# 4647233          True                  NO
# 3339160         False       NOT_MENTIONED
# 1439226         False                  NZ
# 5118553         False                  OM
# 2331565         False                  PA
# 951208          False                  PE
# 4305896         False                  PH
# 5117070         False                  PK
# 1141830          True                  PL
# 2327542          True                  PT
# 529856          False                  PW
# 3709047         False                  QA
# 559817          False  REGISTER_WITHDRAWN
# 2226424          True                  RO
# 246465           True                  RU
# 3600770         False                  SA
# 2964989         False                  SC
# 1252030          True                  SE
# 4138896         False                  SG
# 4106516          True                  SI
# 1668382         False                  SL
# 1173095         False                  ST
# 1137848         False                  SV
# 289516          False                  SY
# 499024          False                  TG
# 1712368         False                  TH
# 2518347         False                  TN
# 3192191         False                  TR
# 5276389         False                  TT
# 3978448         False                  TV
# 4475359         False                  TW
# 492073          False                  TZ
# 1131709         False                  UA
# 1705305         False                  US
# 1356567         False                  UY
# 46030           False                  VC
# 1644891         False                  VE
# 13300           False                  VG
# 10555           False                  VI
# 3195347         False                  VN
# 3005061         False                  VU
# 223727          False                  WS
# 5231521         False                  ZA
# 1629882         False                 NaN

# %%
portcalls['flag_in_pmou'].value_counts(normalize=True)
# Out:
# True     0.697849
# False    0.302151
# Name: flag_in_pmou, dtype: float64

# %%
portcalls['flag'].value_counts(normalize=True)
# Out:
# False    0.966121
# True     0.033879
# Name: flag, dtype: float64

# %%
portcalls['risk'].value_counts().sort_index()
# Out:
# 0.0     608985
# 1.0    2409598
# 2.0      79169
# Name: risk, dtype: int64

# %%
(
    portcalls[['flag_in_pmou', 'risk']]
    .value_counts()
    .sort_index()
    .reset_index()
    .pivot(['flag_in_pmou'], ['risk'], 0)
    .apply(lambda x: x/ x.sum(), axis='columns')
)
# Out:
# risk               0.0       1.0       2.0
# flag_in_pmou
# False         0.163083  0.800071  0.036846
# True          0.211097  0.768234  0.020669

# %% [markdown]
# ## Sent At

# %%
portcalls['Sent.At'].agg(['min', 'max'])
# Out:
# min    2011-10-05 13:37:58
# max    2018-05-24 17:30:42
# Name: Sent.At, dtype: object
